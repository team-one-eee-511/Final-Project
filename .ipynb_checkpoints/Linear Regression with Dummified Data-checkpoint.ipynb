# %%
import sys
import math

# !{sys.executable} -m pip install --upgrade pip

try:
    import numpy as np
except ModuleNotFoundError:
    # !{sys.executable} -m pip install numpy
    import numpy as np
    

try:
    import pandas as pd
except ModuleNotFoundError:
    # !{sys.executable} -m pip install pandas
    import pandas as pd

    
try:
    import matplotlib
    import matplotlib.pyplot as plt
except ModuleNotFoundError:
    # !{sys.executable} -m pip install matplotlib
    import matplotlib.pyplot as plt

    
try:
    import scipy
    import scipy.io
except ModuleNotFoundError:
    # !{sys.executable} -m pip install scipy
    import scipy

        
try:
    import sklearn
except ModuleNotFoundError:
    # !{sys.executable} -m pip install sklearn
    import sklearn

try:
    import mat4py
except ModuleNotFoundError:
    # !{sys.executable} -m pip install mat4py
    import mat4py

        
try:
    import keras
except ModuleNotFoundError:
    # !{sys.executable} -m pip install keras
    import keras
    

try:
    import keras_metrics
except ModuleNotFoundError:
    # !{sys.executable} -m pip install keras_metrics
    import keras_metrics

from keras.models import Sequential
from keras.layers import Dense
import keras_metrics
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Configure Environment

# %%
"""
Make plot outputs appear and be stored within the notebook
"""
# %matplotlib inline

"""
fix random seed for reproducibility
"""
np.random.seed(7)

# %% [markdown]
# ## Inspect Data

# %%
orginal_data = pd.read_csv("eee-all-data.csv", header=0)
orginal_data = orginal_data.sample(frac=0.25)
orginal_data.head()
# Out:
#               TPT  OPERATION  QTY  DOW  SHIFT  SHIFT_TYPE  OWNER  \
# 1104135  0.349778       7568   38    5      2           1      5
# 89872    0.191111       5824   91    5      3           0      5
# 260866   0.320444       7236  224    5      3           0      5
# 317357   0.476444       7399  873    2      0           1      3
# 432861   4.565778       1383  233    3      0           1      4
#
#          BUILD_PRIORITY  BUILD_CATEGORY  BUILD_TYPE  PLATFORM_NAME  \
# 1104135               3               4           4              9
# 89872                 3               4           4             10
# 260866                4               2           1             33
# 317357                3               2           1             11
# 432861                3               2           4             32
#
#          PRODUCT_FAMILY  PACKAGE_NAME  PKGDEVREVSTEP
# 1104135             401             6            663
# 89872               304            20           2530
# 260866              306            44             63
# 317357              308            36           2189
# 432861              183            45             99

# %% [markdown]
# ## Create DataFrame with Dummies

# %%
y_column = ['TPT']
feature_columns = ['BUILD_PRIORITY', 'BUILD_CATEGORY', 'BUILD_TYPE', 'PLATFORM_NAME', 'OPERATION']

subset_features = orginal_data[feature_columns].copy()

dummified_data = orginal_data[['QTY', 'TPT']].copy()

for i in range(len(feature_columns)):
     col = feature_columns[i]
     dumm = pd.get_dummies(subset_features[col], prefix=col)
     dummified_data = pd.concat([dummified_data, dumm], axis=1)

dummified_data.head()
# Out:
#          QTY       TPT  BUILD_PRIORITY_1  BUILD_PRIORITY_2  BUILD_PRIORITY_3  \
# 1104135   38  0.349778                 0                 0                 1
# 89872     91  0.191111                 0                 0                 1
# 260866   224  0.320444                 0                 0                 0
# 317357   873  0.476444                 0                 0                 1
# 432861   233  4.565778                 0                 0                 1
#
#          BUILD_PRIORITY_4  BUILD_CATEGORY_1  BUILD_CATEGORY_2  \
# 1104135                 0                 0                 0
# 89872                   0                 0                 0
# 260866                  1                 0                 1
# 317357                  0                 0                 1
# 432861                  0                 0                 1
#
#          BUILD_CATEGORY_3  BUILD_CATEGORY_4       ...        OPERATION_8778  \
# 1104135                 0                 1       ...                     0
# 89872                   0                 1       ...                     0
# 260866                  0                 0       ...                     0
# 317357                  0                 0       ...                     0
# 432861                  0                 0       ...                     0
#
#          OPERATION_8859  OPERATION_8940  OPERATION_9081  OPERATION_9374  \
# 1104135               0               0               0               0
# 89872                 0               0               0               0
# 260866                0               0               0               0
# 317357                0               0               0               0
# 432861                0               0               0               0
#
#          OPERATION_9375  OPERATION_9376  OPERATION_9384  OPERATION_9385  \
# 1104135               0               0               0               0
# 89872                 0               0               0               0
# 260866                0               0               0               0
# 317357                0               0               0               0
# 432861                0               0               0               0
#
#          OPERATION_9387
# 1104135               0
# 89872                 0
# 260866                0
# 317357                0
# 432861                0
#
# [5 rows x 627 columns]

# %% [markdown]
# ## Parition data to train/test sets

# %%
from sklearn.model_selection import train_test_split

X = dummified_data.drop('TPT', axis=1)
y = dummified_data[['TPT']]
# Split X and y into X_
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
score = regression_model.score(X_test, y_test)
print("score is {}".format(score))
# Out:
# score is -165938011.77664715

# %%
from sklearn.metrics import mean_squared_error

y_predict = regression_model.predict(X_test)

regression_model_mse = mean_squared_error(y_predict, y_test)

print("regression_model_mse is {}".format(regression_model_mse))
# Out:
# regression_model_mse is 189923814078.17444

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for QTY is 0.0015280818684434174
# The coefficient for BUILD_PRIORITY_1 is -795476236.2421662
# The coefficient for BUILD_PRIORITY_2 is -795476239.0766202
# The coefficient for BUILD_PRIORITY_3 is -795476230.9168321
# The coefficient for BUILD_PRIORITY_4 is -795476229.6820834
# The coefficient for BUILD_CATEGORY_1 is 34876512.95965263
# The coefficient for BUILD_CATEGORY_2 is 34876516.16753908
# The coefficient for BUILD_CATEGORY_3 is 34876509.47995438
# The coefficient for BUILD_CATEGORY_4 is 34876514.02728166
# The coefficient for BUILD_TYPE_1 is -789112782.2152478
# The coefficient for BUILD_TYPE_2 is -789112783.3486744
# The coefficient for BUILD_TYPE_3 is -789112791.478259
# The coefficient for BUILD_TYPE_4 is -789112781.8253163
# The coefficient for PLATFORM_NAME_1 is -107727557.29262516
# The coefficient for PLATFORM_NAME_2 is -107727553.63085085
# The coefficient for PLATFORM_NAME_3 is -107727557.5791979
# The coefficient for PLATFORM_NAME_4 is -107727553.4485906
# The coefficient for PLATFORM_NAME_5 is -107727553.66524525
# The coefficient for PLATFORM_NAME_6 is -107727555.01817682
# The coefficient for PLATFORM_NAME_7 is -107727552.19683029
# The coefficient for PLATFORM_NAME_8 is -107727555.79705411
# The coefficient for PLATFORM_NAME_9 is -107727555.99498081
# The coefficient for PLATFORM_NAME_10 is -107727556.79027724
# The coefficient for PLATFORM_NAME_11 is -107727555.93650547
# The coefficient for PLATFORM_NAME_12 is -107727555.37825206
# The coefficient for PLATFORM_NAME_13 is -107727554.63763255
# The coefficient for PLATFORM_NAME_14 is -107727556.15280856
# The coefficient for PLATFORM_NAME_15 is -107727549.77427574
# The coefficient for PLATFORM_NAME_16 is -107727557.49603808
# The coefficient for PLATFORM_NAME_17 is -107727555.42802347
# The coefficient for PLATFORM_NAME_18 is -107727560.3435129
# The coefficient for PLATFORM_NAME_19 is -107727559.59711081
# The coefficient for PLATFORM_NAME_20 is -107727559.96719897
# The coefficient for PLATFORM_NAME_21 is -107727556.21945603
# The coefficient for PLATFORM_NAME_22 is -107727554.82169367
# The coefficient for PLATFORM_NAME_23 is -107727539.70078078
# The coefficient for PLATFORM_NAME_24 is -107727554.69990134
# The coefficient for PLATFORM_NAME_25 is -107727559.39213634
# The coefficient for PLATFORM_NAME_26 is -107727556.27165502
# The coefficient for PLATFORM_NAME_27 is -107727553.58912468
# The coefficient for PLATFORM_NAME_28 is -107727555.54670691
# The coefficient for PLATFORM_NAME_29 is -107727555.52094667
# The coefficient for PLATFORM_NAME_30 is -107727549.97085384
# The coefficient for PLATFORM_NAME_31 is -107727553.48815289
# The coefficient for PLATFORM_NAME_32 is -107727556.059044
# The coefficient for PLATFORM_NAME_33 is -107727556.20449647
# The coefficient for PLATFORM_NAME_34 is -107727555.57921013
# The coefficient for PLATFORM_NAME_35 is -107727540.27354336
# The coefficient for PLATFORM_NAME_36 is 9413708.99414298
# The coefficient for PLATFORM_NAME_37 is -107727552.71005702
# The coefficient for PLATFORM_NAME_38 is -107727551.42265025
# The coefficient for PLATFORM_NAME_39 is -107727539.22802679
# The coefficient for PLATFORM_NAME_40 is -107727557.89409931
# The coefficient for OPERATION_224 is 2401777.4422782655
# The coefficient for OPERATION_225 is 2402101.0751204835
# The coefficient for OPERATION_226 is 2401711.066910783
# The coefficient for OPERATION_227 is 2401704.525027208
# The coefficient for OPERATION_228 is 2401700.876544898
# The coefficient for OPERATION_229 is 2401751.061874342
# The coefficient for OPERATION_230 is 2401693.769465944
# The coefficient for OPERATION_231 is 2401700.8200509464
# The coefficient for OPERATION_232 is 2401702.185036436
# The coefficient for OPERATION_234 is 2401697.540971461
# The coefficient for OPERATION_235 is 2401707.710308505
# The coefficient for OPERATION_236 is 2401707.196313426
# The coefficient for OPERATION_237 is 2401702.5552732274
# The coefficient for OPERATION_239 is 2401716.1271091998
# The coefficient for OPERATION_240 is 2401733.233117029
# The coefficient for OPERATION_241 is 2401768.2813616395
# The coefficient for OPERATION_242 is 2401723.943606861
# The coefficient for OPERATION_244 is 2401706.7030338654
# The coefficient for OPERATION_245 is 2401715.1524710543
# The coefficient for OPERATION_247 is 2401698.7334481175
# The coefficient for OPERATION_248 is 2401704.0917477775
# The coefficient for OPERATION_249 is 2401717.1882623155
# The coefficient for OPERATION_250 is 2401701.947156502
# The coefficient for OPERATION_251 is 2401704.3307923377
# The coefficient for OPERATION_255 is 2401729.700079074
# The coefficient for OPERATION_256 is 2401705.153852878
# The coefficient for OPERATION_260 is 2401700.5252976827
# The coefficient for OPERATION_261 is 2401790.7888910323
# The coefficient for OPERATION_263 is 2401699.05827735
# The coefficient for OPERATION_265 is 2401776.6257101176
# The coefficient for OPERATION_266 is 2401718.5652080444
# The coefficient for OPERATION_268 is 2401752.315858355
# The coefficient for OPERATION_269 is 2401704.1289536143
# The coefficient for OPERATION_273 is 2401749.977913593
# The coefficient for OPERATION_274 is 2401777.089971567
# The coefficient for OPERATION_277 is 2401709.806577754
# The coefficient for OPERATION_279 is 2401705.250549879
# The coefficient for OPERATION_280 is 2401796.764181631
# The coefficient for OPERATION_283 is 2401722.159524421
# The coefficient for OPERATION_286 is 2401735.762981881
# The coefficient for OPERATION_291 is 2401724.1485795276
# The coefficient for OPERATION_294 is 2401708.897571588
# The coefficient for OPERATION_308 is 2401706.442181169
# The coefficient for OPERATION_309 is 2401713.376154175
# The coefficient for OPERATION_312 is 2401710.5026626596
# The coefficient for OPERATION_317 is 2401705.3245406724
# The coefficient for OPERATION_322 is 2401705.1769200456
# The coefficient for OPERATION_324 is 2401765.508733876
# The coefficient for OPERATION_325 is 2401767.36239944
# The coefficient for OPERATION_327 is 2401707.1536165657
# The coefficient for OPERATION_469 is 2401711.777154077
# The coefficient for OPERATION_683 is 2401743.887011391
# The coefficient for OPERATION_684 is 2401712.6852580346
# The coefficient for OPERATION_685 is 2401726.525381662
# The coefficient for OPERATION_757 is 2401703.6530207554
# The coefficient for OPERATION_763 is 2401791.0617405274
# The coefficient for OPERATION_774 is 2401714.9714670805
# The coefficient for OPERATION_777 is 2401707.529484166
# The coefficient for OPERATION_781 is 2401707.1736304006
# The coefficient for OPERATION_787 is 2401713.784815578
# The coefficient for OPERATION_792 is 2401703.459759418
# The coefficient for OPERATION_799 is 2401703.629804434
# The coefficient for OPERATION_800 is 2401694.742330092
# The coefficient for OPERATION_801 is 2401698.426005359
# The coefficient for OPERATION_803 is 2401718.2172301626
# The coefficient for OPERATION_903 is 2401700.7595937736
# The coefficient for OPERATION_1093 is 2401707.132164371
# The coefficient for OPERATION_1117 is 2401701.0704195728
# The coefficient for OPERATION_1120 is 2401716.7642923854
# The coefficient for OPERATION_1133 is 2401711.238022358
# The coefficient for OPERATION_1143 is 2401702.5931423833
# The coefficient for OPERATION_1168 is 2401707.1107346117
# The coefficient for OPERATION_1169 is 2401709.732702925
# The coefficient for OPERATION_1177 is 2401763.7016481967
# The coefficient for OPERATION_1180 is 2401754.964769862
# The coefficient for OPERATION_1184 is 2401700.535882624
# The coefficient for OPERATION_1200 is 2401858.099279399
# The coefficient for OPERATION_1204 is 2401713.4480924765
# The coefficient for OPERATION_1206 is 2401727.3636959563
# The coefficient for OPERATION_1211 is 2401698.706363891
# The coefficient for OPERATION_1220 is 2401700.7168114767
# The coefficient for OPERATION_1221 is 2401747.899157681
# The coefficient for OPERATION_1239 is 2401719.8549691704
# The coefficient for OPERATION_1262 is 2401708.3946796786
# The coefficient for OPERATION_1266 is 2401703.74502163
# The coefficient for OPERATION_1267 is 2401704.165608895
# The coefficient for OPERATION_1273 is 2401703.1398748304
# The coefficient for OPERATION_1303 is 2401718.0739817694
# The coefficient for OPERATION_1306 is 2401696.8712469507
# The coefficient for OPERATION_1315 is 2401759.306549769
# The coefficient for OPERATION_1320 is 2401706.9374661315
# The coefficient for OPERATION_1322 is 2401702.6152397282
# The coefficient for OPERATION_1323 is 2401706.2801179662
# The coefficient for OPERATION_1344 is 2401724.2447686363
# The coefficient for OPERATION_1345 is 2401701.3575144913
# The coefficient for OPERATION_1346 is 2401709.1848326297
# The coefficient for OPERATION_1347 is 2401741.636707127
# The coefficient for OPERATION_1348 is 2401704.886834794
# The coefficient for OPERATION_1357 is 2401712.738504555
# The coefficient for OPERATION_1377 is 2401716.3612933867
# The coefficient for OPERATION_1379 is 2401701.9505985905
# The coefficient for OPERATION_1381 is 2401705.3481654115
# The coefficient for OPERATION_1383 is 2401710.400050318
# The coefficient for OPERATION_1384 is 2401700.882192122
# The coefficient for OPERATION_1388 is 2401706.829157859
# The coefficient for OPERATION_1389 is 2401706.145183988
# The coefficient for OPERATION_1390 is 2401706.959198994
# The coefficient for OPERATION_1392 is 2401706.087283615
# The coefficient for OPERATION_1394 is 2401706.9684048067
# The coefficient for OPERATION_1395 is 2401706.0072922
# The coefficient for OPERATION_1396 is 2401701.1216764925
# The coefficient for OPERATION_1397 is 2401707.0235076314
# The coefficient for OPERATION_1398 is 2401734.0687000677
# The coefficient for OPERATION_1400 is 2401702.979254141
# The coefficient for OPERATION_1403 is 2401706.395098706
# The coefficient for OPERATION_1404 is 2401703.901961823
# The coefficient for OPERATION_1405 is 2401703.731974061
# The coefficient for OPERATION_1406 is 2401705.4550898075
# The coefficient for OPERATION_1407 is 2401704.049333999
# The coefficient for OPERATION_1408 is 2401709.139573142
# The coefficient for OPERATION_1409 is 2401703.5876248623
# The coefficient for OPERATION_1410 is 2401728.5526449457
# The coefficient for OPERATION_1411 is 2401708.208787502
# The coefficient for OPERATION_1415 is 2401708.427763355
# The coefficient for OPERATION_1418 is 2401706.6703199595
# The coefficient for OPERATION_1419 is 2401705.827890333
# The coefficient for OPERATION_1421 is 2401705.121726921
# The coefficient for OPERATION_1425 is 2401735.465789457
# The coefficient for OPERATION_1426 is 2401716.256459646
# The coefficient for OPERATION_1428 is 2401713.845884514
# The coefficient for OPERATION_1435 is 2401724.9179969486
# The coefficient for OPERATION_1437 is 2401701.804201575
# The coefficient for OPERATION_1438 is 2401705.8052048944
# The coefficient for OPERATION_1439 is 2401709.8155856
# The coefficient for OPERATION_1440 is 2401707.400816912
# The coefficient for OPERATION_1441 is 2401725.0900271833
# The coefficient for OPERATION_1442 is 2401704.8334281016
# The coefficient for OPERATION_1458 is 2401702.84286632
# The coefficient for OPERATION_1459 is 2401714.8022830375
# The coefficient for OPERATION_1460 is 2401708.8044312806
# The coefficient for OPERATION_1465 is 2401740.91932829
# The coefficient for OPERATION_1466 is 2401708.2141088955
# The coefficient for OPERATION_1467 is 2401727.4215816613
# The coefficient for OPERATION_1472 is 2401718.85883635
# The coefficient for OPERATION_1483 is 2401702.449406892
# The coefficient for OPERATION_1485 is 2401738.991691692
# The coefficient for OPERATION_1574 is 2401697.868445394
# The coefficient for OPERATION_1575 is 2401718.833146423
# The coefficient for OPERATION_1576 is 2401704.193241539
# The coefficient for OPERATION_1577 is 2401700.2519430355
# The coefficient for OPERATION_1602 is 2401703.225811243
# The coefficient for OPERATION_1603 is 2401702.633733891
# The coefficient for OPERATION_1609 is 2401686.2063680636
# The coefficient for OPERATION_1612 is 2401711.6525039896
# The coefficient for OPERATION_1613 is 2401747.004445933
# The coefficient for OPERATION_1642 is 2401705.8053301456
# The coefficient for OPERATION_1644 is 2401703.8194118813
# The coefficient for OPERATION_1645 is 2401704.6736791767
# The coefficient for OPERATION_1663 is 2401707.144800538
# The coefficient for OPERATION_1674 is 2401702.349176827
# The coefficient for OPERATION_1677 is 2401706.5617042813
# The coefficient for OPERATION_1682 is 2401705.9800844435
# The coefficient for OPERATION_1689 is 2401717.344415096
# The coefficient for OPERATION_1690 is 2401710.168865967
# The coefficient for OPERATION_1692 is 2401709.044067093
# The coefficient for OPERATION_1696 is 2401707.647480702
# The coefficient for OPERATION_1699 is 2401706.4974698275
# The coefficient for OPERATION_1700 is 2401706.5827553403
# The coefficient for OPERATION_1707 is 2401703.259266867
# The coefficient for OPERATION_1708 is 2401713.2940888335
# The coefficient for OPERATION_1709 is 2401706.657507372
# The coefficient for OPERATION_1710 is 2401744.677727163
# The coefficient for OPERATION_1720 is 2401711.397068348
# The coefficient for OPERATION_1728 is 2401762.257907166
# The coefficient for OPERATION_1730 is 2401716.016545078
# The coefficient for OPERATION_1740 is 2401725.919737049
# The coefficient for OPERATION_1742 is 2401701.820953683
# The coefficient for OPERATION_1743 is 2401706.0636099717
# The coefficient for OPERATION_1746 is 2401740.0370060652
# The coefficient for OPERATION_1766 is 2401706.998021044
# The coefficient for OPERATION_1767 is 2401709.14445439
# The coefficient for OPERATION_1768 is 2401704.7725847587
# The coefficient for OPERATION_1769 is 2401712.9904723484
# The coefficient for OPERATION_1770 is 2401707.3969777077
# The coefficient for OPERATION_1783 is 2401701.190220905
# The coefficient for OPERATION_1793 is 2401709.2938335612
# The coefficient for OPERATION_1797 is 2401708.453448044
# The coefficient for OPERATION_1798 is 2401706.0297003184
# The coefficient for OPERATION_1803 is 2401706.3001401676
# The coefficient for OPERATION_1839 is 2401716.0409522923
# The coefficient for OPERATION_1842 is 2401703.5640367744
# The coefficient for OPERATION_1843 is 2401709.0246220874
# The coefficient for OPERATION_1852 is 2401715.96092933
# The coefficient for OPERATION_1853 is 2401708.0033591837
# The coefficient for OPERATION_1859 is 2401705.55887587
# The coefficient for OPERATION_1862 is 2401749.3559920546
# The coefficient for OPERATION_1863 is 2401739.9503489584
# The coefficient for OPERATION_1864 is 2401701.4775511306
# The coefficient for OPERATION_1895 is 2401706.567728251
# The coefficient for OPERATION_1896 is 2401705.9115408063
# The coefficient for OPERATION_1898 is 2401712.019990869
# The coefficient for OPERATION_1965 is 2401803.653456422
# The coefficient for OPERATION_1966 is 2401755.1770035396
# The coefficient for OPERATION_1975 is 2401706.8235517666
# The coefficient for OPERATION_1976 is 2401728.534543656
# The coefficient for OPERATION_1980 is 2401705.259471899
# The coefficient for OPERATION_1987 is 2401725.448395999
# The coefficient for OPERATION_1998 is 2401709.658877751
# The coefficient for OPERATION_2001 is 2401708.237590457
# The coefficient for OPERATION_2002 is 2401706.0989115024
# The coefficient for OPERATION_2007 is 2401705.3153825346
# The coefficient for OPERATION_2009 is 2401712.802168213
# The coefficient for OPERATION_2014 is 2401706.685883103
# The coefficient for OPERATION_2016 is 2401725.7116086707
# The coefficient for OPERATION_2020 is 2401774.8665820253
# The coefficient for OPERATION_2024 is 2401758.301592642
# The coefficient for OPERATION_2025 is 2401707.87826743
# The coefficient for OPERATION_2026 is 2401713.55521673
# The coefficient for OPERATION_2027 is 2401713.1393881813
# The coefficient for OPERATION_2030 is 2401714.145459244
# The coefficient for OPERATION_2031 is 2401715.710911065
# The coefficient for OPERATION_2034 is 2401719.4827915765
# The coefficient for OPERATION_2036 is 2401706.084228836
# The coefficient for OPERATION_2037 is 2401706.1495738286
# The coefficient for OPERATION_2039 is 2401748.7156909173
# The coefficient for OPERATION_2040 is 2401705.371363569
# The coefficient for OPERATION_2042 is 2401707.3527519647
# The coefficient for OPERATION_2049 is 2401720.222628072
# The coefficient for OPERATION_2065 is 2401709.986157514
# The coefficient for OPERATION_2066 is 2401740.7728530285
# The coefficient for OPERATION_2067 is 2401734.879874889
# The coefficient for OPERATION_2068 is 2401711.4728530743
# The coefficient for OPERATION_2069 is 2401709.1141966847
# The coefficient for OPERATION_2070 is 2401708.5365095427
# The coefficient for OPERATION_2071 is 2401713.6320374347
# The coefficient for OPERATION_2077 is 2401703.148318537
# The coefficient for OPERATION_2078 is 2401709.331499525
# The coefficient for OPERATION_2079 is 2401719.7995543424
# The coefficient for OPERATION_2080 is 2401707.2209100155
# The coefficient for OPERATION_2081 is 2401720.0782027147
# The coefficient for OPERATION_2082 is 2401743.6513719615
# The coefficient for OPERATION_2092 is 2401714.0389455017
# The coefficient for OPERATION_2093 is 2401708.0926140454
# The coefficient for OPERATION_2096 is 2401716.6556729153
# The coefficient for OPERATION_2098 is 2401704.9027764723
# The coefficient for OPERATION_2099 is 2401735.2736961525
# The coefficient for OPERATION_2100 is 2401755.474394045
# The coefficient for OPERATION_2101 is 2401720.4717121143
# The coefficient for OPERATION_2103 is 2401708.143053199
# The coefficient for OPERATION_2105 is 2401704.596584829
# The coefficient for OPERATION_2106 is 2401748.5468339142
# The coefficient for OPERATION_2107 is 2401704.8848352283
# The coefficient for OPERATION_2111 is 2401700.8564048694
# The coefficient for OPERATION_2125 is 2401706.2520949217
# The coefficient for OPERATION_2131 is 2401702.1956807664
# The coefficient for OPERATION_2133 is 2401734.6700482015
# The coefficient for OPERATION_2134 is 2401709.626096314
# The coefficient for OPERATION_2135 is 2401701.360562602
# The coefficient for OPERATION_2140 is 2401717.1495374176
# The coefficient for OPERATION_2141 is 2401708.615575311
# The coefficient for OPERATION_2142 is 2401701.7092401795
# The coefficient for OPERATION_2144 is 2401751.235079866
# The coefficient for OPERATION_2145 is 2401708.8823105376
# The coefficient for OPERATION_2146 is 2401718.07203927
# The coefficient for OPERATION_2147 is 2401706.4552212534
# The coefficient for OPERATION_2148 is 2401700.4545724583
# The coefficient for OPERATION_2149 is 2401700.256563596
# The coefficient for OPERATION_2150 is 2401728.5680941325
# The coefficient for OPERATION_2151 is 2401824.312993336
# The coefficient for OPERATION_2155 is -0.00012704823166131973
# The coefficient for OPERATION_2156 is 2401704.8627442904
# The coefficient for OPERATION_2160 is 2401701.7518180613
# The coefficient for OPERATION_2162 is 2401749.908203558
# The coefficient for OPERATION_2163 is 2401773.4613763746
# The coefficient for OPERATION_2164 is 2401757.8398522064
# The coefficient for OPERATION_2165 is 2401700.8335383106
# The coefficient for OPERATION_2167 is 2401752.419641058
# The coefficient for OPERATION_2169 is 2401725.0002320977
# The coefficient for OPERATION_2171 is 2401715.164131049
# The coefficient for OPERATION_2177 is 2401705.898087673
# The coefficient for OPERATION_2182 is 2401714.4342882093
# The coefficient for OPERATION_2188 is 2401703.526561007
# The coefficient for OPERATION_2189 is 2401704.444888805
# The coefficient for OPERATION_2192 is 2401714.1427801284
# The coefficient for OPERATION_2204 is 2401732.6644198764
# The coefficient for OPERATION_2206 is 2401708.2953439075
# The coefficient for OPERATION_2208 is 2401707.658710743
# The coefficient for OPERATION_2209 is 2401706.071051161
# The coefficient for OPERATION_2210 is 2401704.650406826
# The coefficient for OPERATION_2211 is 2401706.026664022
# The coefficient for OPERATION_2212 is 2401703.30543317
# The coefficient for OPERATION_2213 is 2401735.9606122794
# The coefficient for OPERATION_2215 is 2401700.9307693643
# The coefficient for OPERATION_2216 is 2401712.3194261976
# The coefficient for OPERATION_2219 is 2401706.2674935735
# The coefficient for OPERATION_2220 is 2401718.6745401993
# The coefficient for OPERATION_2221 is 2401728.7941947132
# The coefficient for OPERATION_2223 is 2401728.644703689
# The coefficient for OPERATION_2224 is 2401790.6874850886
# The coefficient for OPERATION_2226 is 2401705.4238040103
# The coefficient for OPERATION_2233 is 2401830.59507755
# The coefficient for OPERATION_2234 is 2401729.7299929447
# The coefficient for OPERATION_2235 is 2401709.0373942624
# The coefficient for OPERATION_2236 is 2401699.4153329907
# The coefficient for OPERATION_2237 is 2401741.619089259
# The coefficient for OPERATION_2238 is 2401700.955449609
# The coefficient for OPERATION_2239 is 2401702.7245022375
# The coefficient for OPERATION_2241 is 2401712.6284845313
# The coefficient for OPERATION_2242 is 2401710.224600829
# The coefficient for OPERATION_2243 is 2401700.763516592
# The coefficient for OPERATION_2244 is 2401703.4946109
# The coefficient for OPERATION_2245 is 2401700.4599215733
# The coefficient for OPERATION_2246 is 2401703.1071601138
# The coefficient for OPERATION_2255 is 2401703.950841102
# The coefficient for OPERATION_2258 is 2401729.7054342753
# The coefficient for OPERATION_2262 is 2401757.198911712
# The coefficient for OPERATION_2263 is 2401803.3853747332
# The coefficient for OPERATION_2264 is 2401701.3054340053
# The coefficient for OPERATION_2266 is 2401715.4823573944
# The coefficient for OPERATION_2277 is 2401710.963444091
# The coefficient for OPERATION_2289 is 2401740.158410958
# The coefficient for OPERATION_2308 is 2401707.112558565
# The coefficient for OPERATION_2312 is 2401701.265783837
# The coefficient for OPERATION_2323 is 2401702.2883347534
# The coefficient for OPERATION_2324 is 2401702.985507492
# The coefficient for OPERATION_2325 is 2401702.1729846643
# The coefficient for OPERATION_2326 is 2401703.1407103334
# The coefficient for OPERATION_2327 is 2401700.767875283
# The coefficient for OPERATION_2328 is 2401700.856407849
# The coefficient for OPERATION_2329 is 2401701.3992646546
# The coefficient for OPERATION_2330 is 2401700.62059587
# The coefficient for OPERATION_2332 is 2401701.4082251703
# The coefficient for OPERATION_2333 is 2401702.489102099
# The coefficient for OPERATION_2334 is 2401702.990990879
# The coefficient for OPERATION_2335 is 2401777.448109549
# The coefficient for OPERATION_2336 is 2401993.813785413
# The coefficient for OPERATION_2341 is 2401701.3188057756
# The coefficient for OPERATION_2343 is 2401707.0685975645
# The coefficient for OPERATION_2344 is 2401707.4676021524
# The coefficient for OPERATION_2345 is 2401707.5047902185
# The coefficient for OPERATION_2346 is 2401708.8634546204
# The coefficient for OPERATION_2347 is 2401707.1682775193
# The coefficient for OPERATION_2348 is 2401719.702824058
# The coefficient for OPERATION_2350 is 2401708.4575657235
# The coefficient for OPERATION_2355 is 2401708.9258656437
# The coefficient for OPERATION_2356 is 2401709.487621345
# The coefficient for OPERATION_2377 is -1.2732925824820995e-11
# The coefficient for OPERATION_2477 is 2401758.378721653
# The coefficient for OPERATION_2478 is 2401777.725558148
# The coefficient for OPERATION_2480 is 2401706.7651697267
# The coefficient for OPERATION_2494 is 2401711.3644317426
# The coefficient for OPERATION_2558 is 2401737.1963701053
# The coefficient for OPERATION_2700 is 2401703.089895927
# The coefficient for OPERATION_2750 is 2401719.078627837
# The coefficient for OPERATION_2812 is 2401701.13805657
# The coefficient for OPERATION_2925 is 2401772.487211586
# The coefficient for OPERATION_3021 is 2401701.281206534
# The coefficient for OPERATION_3077 is 2401760.773550223
# The coefficient for OPERATION_3083 is 2401716.0096346973
# The coefficient for OPERATION_3099 is 2401724.6099787345
# The coefficient for OPERATION_3102 is 2401709.9223004477
# The coefficient for OPERATION_3103 is 2401762.853525602
# The coefficient for OPERATION_3126 is 2401923.846044765
# The coefficient for OPERATION_3148 is 2401708.920628817
# The coefficient for OPERATION_3149 is 2401701.897482321
# The coefficient for OPERATION_3195 is 2401705.1897829818
# The coefficient for OPERATION_3196 is 2401705.346974697
# The coefficient for OPERATION_3197 is 2401708.923980146
# The coefficient for OPERATION_3198 is 2401703.259941578
# The coefficient for OPERATION_3199 is 2401719.5199040067
# The coefficient for OPERATION_4212 is 2401705.7727268077
# The coefficient for OPERATION_4249 is 2401753.888050803
# The coefficient for OPERATION_4324 is 2401747.2951703323
# The coefficient for OPERATION_4326 is 2401729.910910081
# The coefficient for OPERATION_4327 is 2401716.007030336
# The coefficient for OPERATION_4368 is 2401738.38807457
# The coefficient for OPERATION_5165 is 2401703.1752736927
# The coefficient for OPERATION_5824 is 2401704.68939773
# The coefficient for OPERATION_5825 is 2401703.075827871
# The coefficient for OPERATION_5826 is 2401704.5102365017
# The coefficient for OPERATION_5827 is 2401702.274791053
# The coefficient for OPERATION_6298 is 2401708.5174348247
# The coefficient for OPERATION_6299 is 2401709.2088436247
# The coefficient for OPERATION_6300 is 2401712.348625907
# The coefficient for OPERATION_6301 is 2401703.499400528
# The coefficient for OPERATION_6302 is 2401705.725735564
# The coefficient for OPERATION_6312 is 2401710.686020522
# The coefficient for OPERATION_6336 is 2401799.003720777
# The coefficient for OPERATION_6337 is 8.810729923425242e-12
# The coefficient for OPERATION_6338 is 2401743.579250438
# The coefficient for OPERATION_6339 is 2401807.373889355
# The coefficient for OPERATION_6370 is 2401717.890138899
# The coefficient for OPERATION_6381 is -1.1230127938688383e-11
# The coefficient for OPERATION_6385 is 2401737.2175443675
# The coefficient for OPERATION_6386 is 2401705.646062232
# The coefficient for OPERATION_6387 is 2401706.524706147
# The coefficient for OPERATION_6388 is 2401742.915412927
# The coefficient for OPERATION_6389 is 2401709.7949149804
# The coefficient for OPERATION_6415 is 2401744.1205935017
# The coefficient for OPERATION_6416 is 2401719.974928648
# The coefficient for OPERATION_6417 is 2401718.2102628946
# The coefficient for OPERATION_6418 is 2401723.5212931307
# The coefficient for OPERATION_6421 is 2401741.725546482
# The coefficient for OPERATION_6435 is 2401781.706900062
# The coefficient for OPERATION_6436 is 2401708.957058404
# The coefficient for OPERATION_6437 is 2401721.567442367
# The coefficient for OPERATION_6438 is 2401698.7917268877
# The coefficient for OPERATION_6439 is 2401703.8929869784
# The coefficient for OPERATION_6440 is 2401748.737074441
# The coefficient for OPERATION_6452 is 2401704.0319717317
# The coefficient for OPERATION_6460 is 2401722.0058778967
# The coefficient for OPERATION_6461 is 2401704.925708115
# The coefficient for OPERATION_6463 is 2401708.2150582927
# The coefficient for OPERATION_6478 is 2401770.249860984
# The coefficient for OPERATION_6489 is 2401773.838589361
# The coefficient for OPERATION_6490 is 2401790.752348965
# The coefficient for OPERATION_6525 is 2401705.5990684805
# The coefficient for OPERATION_6527 is 2401705.694320491
# The coefficient for OPERATION_6549 is 2401709.2858522288
# The coefficient for OPERATION_6550 is 2401709.321299691
# The coefficient for OPERATION_6551 is 2401706.569763261
# The coefficient for OPERATION_6552 is 2401709.1562227774
# The coefficient for OPERATION_6559 is 2401703.147124797
# The coefficient for OPERATION_6565 is 2401706.076003861
# The coefficient for OPERATION_6567 is 2401706.5212570443
# The coefficient for OPERATION_6568 is 2401710.837193669
# The coefficient for OPERATION_6569 is 2401744.523333648
# The coefficient for OPERATION_6605 is 2401707.8453967776
# The coefficient for OPERATION_6608 is 2401706.1876075417
# The coefficient for OPERATION_6610 is 2401701.140516069
# The coefficient for OPERATION_6618 is 2401701.443200568
# The coefficient for OPERATION_6626 is 1.0391687510491465e-13
# The coefficient for OPERATION_6649 is 2401740.646993897
# The coefficient for OPERATION_6684 is 2401710.058853368
# The coefficient for OPERATION_6690 is 2401701.1531680604
# The coefficient for OPERATION_6692 is 2401701.2257384164
# The coefficient for OPERATION_6694 is 2401704.01934471
# The coefficient for OPERATION_6696 is 2401706.5710708424
# The coefficient for OPERATION_6698 is 2401708.8130734693
# The coefficient for OPERATION_6699 is 2401705.5313043804
# The coefficient for OPERATION_6702 is 2401702.117809139
# The coefficient for OPERATION_6715 is 2401701.529395869
# The coefficient for OPERATION_6716 is 2401712.6051955977
# The coefficient for OPERATION_6720 is 2401733.9568364536
# The coefficient for OPERATION_6727 is 2401701.329777701
# The coefficient for OPERATION_6744 is 2401755.478819308
# The coefficient for OPERATION_6794 is 2401714.394458917
# The coefficient for OPERATION_6797 is 2401941.489385068
# The coefficient for OPERATION_6800 is 5.5067062021407764e-14
# The coefficient for OPERATION_6805 is 2401718.6261283215
# The coefficient for OPERATION_6849 is 2401705.6538527836
# The coefficient for OPERATION_6895 is 2401787.8850921057
# The coefficient for OPERATION_6901 is 2401701.857943434
# The coefficient for OPERATION_6904 is 2401870.280203373
# The coefficient for OPERATION_6905 is 2401856.6614390723
# The coefficient for OPERATION_6940 is 2401700.0228228206
# The coefficient for OPERATION_6984 is 2401704.2072829367
# The coefficient for OPERATION_6994 is 2401730.9526507226
# The coefficient for OPERATION_6998 is 2401701.260194269
# The coefficient for OPERATION_7021 is 1.8829382497642655e-13
# The coefficient for OPERATION_7054 is 2401759.0186115373
# The coefficient for OPERATION_7055 is 2401733.449915301
# The coefficient for OPERATION_7056 is 2401758.1711595734
# The coefficient for OPERATION_7057 is 2401732.0202064845
# The coefficient for OPERATION_7058 is 2401734.8428522614
# The coefficient for OPERATION_7059 is 2401703.9658867596
# The coefficient for OPERATION_7062 is 2401737.286352342
# The coefficient for OPERATION_7098 is 2401700.7410771046
# The coefficient for OPERATION_7114 is 2401701.2492376845
# The coefficient for OPERATION_7118 is 2401701.212293265
# The coefficient for OPERATION_7132 is 2401721.6088734944
# The coefficient for OPERATION_7140 is 2401709.9396916805
# The coefficient for OPERATION_7141 is 2401703.206096272
# The coefficient for OPERATION_7142 is 2401702.421430116
# The coefficient for OPERATION_7143 is 2401828.5987213287
# The coefficient for OPERATION_7153 is 3.552713678800501e-14
# The coefficient for OPERATION_7155 is 2401702.946166016
# The coefficient for OPERATION_7156 is 2401701.841401431
# The coefficient for OPERATION_7157 is 2401704.206367807
# The coefficient for OPERATION_7158 is 2401705.2338434183
# The coefficient for OPERATION_7162 is 2401705.377567662
# The coefficient for OPERATION_7168 is 2401743.662577332
# The coefficient for OPERATION_7170 is 2401817.208372979
# The coefficient for OPERATION_7180 is 2401703.304622271
# The coefficient for OPERATION_7233 is 2401799.1139055258
# The coefficient for OPERATION_7235 is 2401733.2784264614
# The coefficient for OPERATION_7236 is 2401702.0321781114
# The coefficient for OPERATION_7257 is 2401705.079218329
# The coefficient for OPERATION_7283 is 2401706.9094555266
# The coefficient for OPERATION_7288 is 2401709.66128375
# The coefficient for OPERATION_7374 is 2401768.479706359
# The coefficient for OPERATION_7377 is 2401735.43503256
# The coefficient for OPERATION_7399 is 2401704.31557326
# The coefficient for OPERATION_7468 is 2401747.6349214427
# The coefficient for OPERATION_7469 is 2401703.0967118107
# The coefficient for OPERATION_7470 is 2401729.632453453
# The coefficient for OPERATION_7473 is 2401707.3941032067
# The coefficient for OPERATION_7483 is 2401718.1474008504
# The coefficient for OPERATION_7500 is 2401702.0836467026
# The coefficient for OPERATION_7509 is 2401703.5879807705
# The coefficient for OPERATION_7517 is 2401704.8934593312
# The coefficient for OPERATION_7518 is 2401712.2346483767
# The coefficient for OPERATION_7519 is 2401707.342774164
# The coefficient for OPERATION_7527 is 2401705.7328360323
# The coefficient for OPERATION_7529 is 2401704.787946526
# The coefficient for OPERATION_7541 is 2401703.9116677567
# The coefficient for OPERATION_7563 is 2401702.2380904127
# The coefficient for OPERATION_7568 is 2401704.018766526
# The coefficient for OPERATION_7570 is 2401719.169717805
# The coefficient for OPERATION_7572 is 2401704.4008907746
# The coefficient for OPERATION_7582 is 2401703.2695066705
# The coefficient for OPERATION_7594 is 2401738.636173947
# The coefficient for OPERATION_7623 is 2401713.4624817455
# The coefficient for OPERATION_7624 is 2401730.4509556442
# The coefficient for OPERATION_7633 is 2401746.888564083
# The coefficient for OPERATION_7634 is 2401738.2418046864
# The coefficient for OPERATION_7635 is 2401770.3735096455
# The coefficient for OPERATION_7636 is 2401746.071098454
# The coefficient for OPERATION_7637 is 2401838.9439874236
# The coefficient for OPERATION_7638 is 2401777.586304187
# The coefficient for OPERATION_7645 is 2401704.172682168
# The coefficient for OPERATION_7647 is 2401702.698810188
# The coefficient for OPERATION_7648 is 2401705.991346188
# The coefficient for OPERATION_7658 is 2401709.296470236
# The coefficient for OPERATION_7683 is 2401703.756538817
# The coefficient for OPERATION_7744 is 2401711.6229060832
# The coefficient for OPERATION_7767 is 2401760.279273475
# The coefficient for OPERATION_7784 is 2401724.85865573
# The coefficient for OPERATION_7884 is 2401733.893507943
# The coefficient for OPERATION_7885 is 2401724.852917156
# The coefficient for OPERATION_7886 is 2401721.508929987
# The coefficient for OPERATION_7894 is 2401751.857363783
# The coefficient for OPERATION_7895 is 2401721.5513611
# The coefficient for OPERATION_7896 is 2401730.687979768
# The coefficient for OPERATION_7897 is 2401730.339379484
# The coefficient for OPERATION_7899 is 2401701.577214396
# The coefficient for OPERATION_7900 is 2401750.2376161073
# The coefficient for OPERATION_7901 is 2401705.7687272076
# The coefficient for OPERATION_7904 is 2401730.4873765334
# The coefficient for OPERATION_7905 is 2401714.5451841867
# The coefficient for OPERATION_7906 is 2401723.420093672
# The coefficient for OPERATION_7914 is 2401724.0539365695
# The coefficient for OPERATION_7915 is 2401718.315451192
# The coefficient for OPERATION_7916 is 2401716.4205838954
# The coefficient for OPERATION_7917 is 2401710.207864787
# The coefficient for OPERATION_7930 is 2401713.6390565
# The coefficient for OPERATION_7948 is 2401792.5677303355
# The coefficient for OPERATION_7960 is 2401737.9545938936
# The coefficient for OPERATION_8024 is 2401734.966487319
# The coefficient for OPERATION_8026 is 2401718.4328183886
# The coefficient for OPERATION_8044 is 2401706.129973104
# The coefficient for OPERATION_8072 is 2401742.814917231
# The coefficient for OPERATION_8077 is 2401701.479754813
# The coefficient for OPERATION_8079 is 2401710.7429866437
# The coefficient for OPERATION_8081 is 2401712.4188194564
# The coefficient for OPERATION_8147 is 2401732.0310649313
# The coefficient for OPERATION_8153 is 2401753.061906579
# The coefficient for OPERATION_8154 is 2401719.6299556494
# The coefficient for OPERATION_8156 is 2401708.746284446
# The coefficient for OPERATION_8183 is 2401704.9149038903
# The coefficient for OPERATION_8193 is 2401703.9307064093
# The coefficient for OPERATION_8758 is 2401704.508263506
# The coefficient for OPERATION_8777 is 2401851.5623361254
# The coefficient for OPERATION_8778 is 2401713.2082721633
# The coefficient for OPERATION_8859 is 2401704.8841017378
# The coefficient for OPERATION_8940 is 2401707.4068235336
# The coefficient for OPERATION_9081 is 2401714.3322613323
# The coefficient for OPERATION_9374 is 2401709.3258166206
# The coefficient for OPERATION_9375 is 2401711.5164203667
# The coefficient for OPERATION_9376 is 2401704.324250069
# The coefficient for OPERATION_9384 is 2401735.0955031277
# The coefficient for OPERATION_9385 is 0.0
# The coefficient for OPERATION_9387 is 2401701.240325725
