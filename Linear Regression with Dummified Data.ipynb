# %%
import sys
import math

# !{sys.executable} -m pip install --upgrade pip

try:
    import numpy as np
except ModuleNotFoundError:
    # !{sys.executable} -m pip install numpy
    import numpy as np
    

try:
    import pandas as pd
except ModuleNotFoundError:
    # !{sys.executable} -m pip install pandas
    import pandas as pd

    
try:
    import matplotlib
    import matplotlib.pyplot as plt
except ModuleNotFoundError:
    # !{sys.executable} -m pip install matplotlib
    import matplotlib.pyplot as plt

    
try:
    import scipy
    import scipy.io
except ModuleNotFoundError:
    # !{sys.executable} -m pip install scipy
    import scipy

        
try:
    import sklearn
except ModuleNotFoundError:
    # !{sys.executable} -m pip install sklearn
    import sklearn

try:
    import mat4py
except ModuleNotFoundError:
    # !{sys.executable} -m pip install mat4py
    import mat4py

        
try:
    import keras
except ModuleNotFoundError:
    # !{sys.executable} -m pip install keras
    import keras
    

try:
    import keras_metrics
except ModuleNotFoundError:
    # !{sys.executable} -m pip install keras_metrics
    import keras_metrics

from keras.models import Sequential
from keras.layers import Dense
import keras_metrics
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Configure Environment

# %%
"""
Make plot outputs appear and be stored within the notebook
"""
# %matplotlib inline

"""
fix random seed for reproducibility
"""
np.random.seed(7)

# %% [markdown]
# ## Inspect Data

# %%
orginal_data = pd.read_csv("eee-all-data.csv", header=0)
orginal_data = orginal_data.sample(frac=0.25)
orginal_data.head()
# Out:
#               TPT  OPERATION  QTY  DOW  SHIFT  SHIFT_TYPE  OWNER  \
# 1104135  0.349778       7568   38    5      2           1      5
# 89872    0.191111       5824   91    5      3           0      5
# 260866   0.320444       7236  224    5      3           0      5
# 317357   0.476444       7399  873    2      0           1      3
# 432861   4.565778       1383  233    3      0           1      4
#
#          BUILD_PRIORITY  BUILD_CATEGORY  BUILD_TYPE  PLATFORM_NAME  \
# 1104135               3               4           4              9
# 89872                 3               4           4             10
# 260866                4               2           1             33
# 317357                3               2           1             11
# 432861                3               2           4             32
#
#          PRODUCT_FAMILY  PACKAGE_NAME  PKGDEVREVSTEP
# 1104135             401             6            663
# 89872               304            20           2530
# 260866              306            44             63
# 317357              308            36           2189
# 432861              183            45             99

# %% [markdown]
# ## Create DataFrame with Dummies

# %%
y_column = ['TPT']
# feature_columns = ['BUILD_PRIORITY', 'BUILD_CATEGORY', 'BUILD_TYPE', 'PLATFORM_NAME', 'OPERATION']
feature_columns = ['BUILD_PRIORITY', 'BUILD_CATEGORY', 'BUILD_TYPE', 'PLATFORM_NAME']

subset_features = orginal_data[feature_columns].copy()

dummified_data = orginal_data[[ 'TPT']].copy()

for i in range(len(feature_columns)):
     col = feature_columns[i]
     dumm = pd.get_dummies(subset_features[col], prefix=col)
     dummified_data = pd.concat([dummified_data, dumm], axis=1)

dummified_data.head()
# Out:
#               TPT  OPERATION_224  OPERATION_225  OPERATION_226  OPERATION_227  \
# 1104135  0.349778              0              0              0              0
# 89872    0.191111              0              0              0              0
# 260866   0.320444              0              0              0              0
# 317357   0.476444              0              0              0              0
# 432861   4.565778              0              0              0              0
#
#          OPERATION_228  OPERATION_229  OPERATION_230  OPERATION_231  \
# 1104135              0              0              0              0
# 89872                0              0              0              0
# 260866               0              0              0              0
# 317357               0              0              0              0
# 432861               0              0              0              0
#
#          OPERATION_232       ...        OPERATION_8778  OPERATION_8859  \
# 1104135              0       ...                     0               0
# 89872                0       ...                     0               0
# 260866               0       ...                     0               0
# 317357               0       ...                     0               0
# 432861               0       ...                     0               0
#
#          OPERATION_8940  OPERATION_9081  OPERATION_9374  OPERATION_9375  \
# 1104135               0               0               0               0
# 89872                 0               0               0               0
# 260866                0               0               0               0
# 317357                0               0               0               0
# 432861                0               0               0               0
#
#          OPERATION_9376  OPERATION_9384  OPERATION_9385  OPERATION_9387
# 1104135               0               0               0               0
# 89872                 0               0               0               0
# 260866                0               0               0               0
# 317357                0               0               0               0
# 432861                0               0               0               0
#
# [5 rows x 574 columns]

# %% [markdown]
# ## Parition data to train/test sets

# %%
from sklearn.model_selection import train_test_split

X = dummified_data.drop('TPT', axis=1)
y = dummified_data[['TPT']]
# Split X and y into X_
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
score = regression_model.score(X_test, y_test)
print("score is {}".format(score))
# Out:
# score is -1.792170404560703e+18

# %%
from sklearn.metrics import mean_squared_error

y_predict = regression_model.predict(X_test)

regression_model_mse = mean_squared_error(y_predict, y_test)

print("regression_model_mse is {}".format(regression_model_mse))
# Out:
# regression_model_mse is 2.051222821200951e+21

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for OPERATION_224 is 36811415852.39878
# The coefficient for OPERATION_225 is 36811416175.08716
# The coefficient for OPERATION_226 is 36811415782.31146
# The coefficient for OPERATION_227 is 36811415775.87561
# The coefficient for OPERATION_228 is 36811415774.620636
# The coefficient for OPERATION_229 is 36811415823.87985
# The coefficient for OPERATION_230 is 36811415770.01117
# The coefficient for OPERATION_231 is 36811415775.631714
# The coefficient for OPERATION_232 is 36811415775.10309
# The coefficient for OPERATION_234 is 36811415770.57637
# The coefficient for OPERATION_235 is 36811415778.904465
# The coefficient for OPERATION_236 is 36811415778.12984
# The coefficient for OPERATION_237 is 36811415773.65515
# The coefficient for OPERATION_239 is 36811415787.0051
# The coefficient for OPERATION_240 is 36811415804.25587
# The coefficient for OPERATION_241 is 36811415838.994644
# The coefficient for OPERATION_242 is 36811415794.579704
# The coefficient for OPERATION_244 is 36811415777.499405
# The coefficient for OPERATION_245 is 36811415786.0428
# The coefficient for OPERATION_247 is 36811415771.90531
# The coefficient for OPERATION_248 is 36811415777.40017
# The coefficient for OPERATION_249 is 36811415789.28773
# The coefficient for OPERATION_250 is 36811415772.8074
# The coefficient for OPERATION_251 is 36811415775.33479
# The coefficient for OPERATION_255 is 36811415800.62528
# The coefficient for OPERATION_256 is 36811415776.76605
# The coefficient for OPERATION_260 is 36811415771.52574
# The coefficient for OPERATION_261 is 36811415862.29666
# The coefficient for OPERATION_263 is 36811415772.353676
# The coefficient for OPERATION_265 is 36811415847.50825
# The coefficient for OPERATION_266 is 36811415791.41193
# The coefficient for OPERATION_268 is 36811415825.36495
# The coefficient for OPERATION_269 is 36811415777.44285
# The coefficient for OPERATION_273 is 36811415820.83499
# The coefficient for OPERATION_274 is 36811415849.69687
# The coefficient for OPERATION_277 is 36811415780.02842
# The coefficient for OPERATION_279 is 36811415776.034775
# The coefficient for OPERATION_280 is 36811415870.050316
# The coefficient for OPERATION_283 is 36811415788.27716
# The coefficient for OPERATION_286 is 36811415806.43114
# The coefficient for OPERATION_291 is 36811415789.60376
# The coefficient for OPERATION_294 is 36811415776.55931
# The coefficient for OPERATION_308 is 36811415774.984695
# The coefficient for OPERATION_309 is 36811415783.48972
# The coefficient for OPERATION_312 is 36811415780.94804
# The coefficient for OPERATION_317 is 36811415772.456696
# The coefficient for OPERATION_322 is 36811415776.21457
# The coefficient for OPERATION_324 is 36811415836.67365
# The coefficient for OPERATION_325 is 36811415844.23792
# The coefficient for OPERATION_327 is 36811415780.12387
# The coefficient for OPERATION_469 is 36811415781.65487
# The coefficient for OPERATION_683 is 36811415814.31094
# The coefficient for OPERATION_684 is 36811415780.305725
# The coefficient for OPERATION_685 is 36811415793.03792
# The coefficient for OPERATION_757 is 36811415772.16303
# The coefficient for OPERATION_763 is 36811415856.42058
# The coefficient for OPERATION_774 is 36811415783.774185
# The coefficient for OPERATION_777 is 36811415776.95073
# The coefficient for OPERATION_781 is 36811415773.93049
# The coefficient for OPERATION_787 is 36811415782.14636
# The coefficient for OPERATION_792 is 36811415772.14359
# The coefficient for OPERATION_799 is 36811415772.77531
# The coefficient for OPERATION_800 is 36811415771.27925
# The coefficient for OPERATION_801 is 36811415770.016045
# The coefficient for OPERATION_803 is 36811415786.5235
# The coefficient for OPERATION_903 is 36811415770.504616
# The coefficient for OPERATION_1093 is 36811415779.70423
# The coefficient for OPERATION_1117 is 36811415772.76566
# The coefficient for OPERATION_1120 is 36811415788.039
# The coefficient for OPERATION_1133 is 36811415779.967064
# The coefficient for OPERATION_1143 is 36811415775.06185
# The coefficient for OPERATION_1168 is 36811415775.375
# The coefficient for OPERATION_1169 is 36811415778.971794
# The coefficient for OPERATION_1177 is 36811415833.67198
# The coefficient for OPERATION_1180 is 36811415826.11584
# The coefficient for OPERATION_1184 is 36811415770.73189
# The coefficient for OPERATION_1200 is 36811415928.424515
# The coefficient for OPERATION_1204 is 36811415780.292305
# The coefficient for OPERATION_1206 is 36811415800.80347
# The coefficient for OPERATION_1211 is 36811415771.371155
# The coefficient for OPERATION_1220 is 36811415771.46646
# The coefficient for OPERATION_1221 is 36811415815.66618
# The coefficient for OPERATION_1239 is 36811415790.37638
# The coefficient for OPERATION_1262 is 36811415774.135284
# The coefficient for OPERATION_1266 is 36811415773.149506
# The coefficient for OPERATION_1267 is 36811415774.54437
# The coefficient for OPERATION_1273 is 36811415772.45377
# The coefficient for OPERATION_1303 is 36811415787.82757
# The coefficient for OPERATION_1306 is 36811415782.78862
# The coefficient for OPERATION_1315 is 36811415827.550995
# The coefficient for OPERATION_1320 is 36811415776.51401
# The coefficient for OPERATION_1322 is 36811415773.27553
# The coefficient for OPERATION_1323 is 36811415774.04149
# The coefficient for OPERATION_1344 is 36811415793.380005
# The coefficient for OPERATION_1345 is 36811415770.56416
# The coefficient for OPERATION_1346 is 36811415778.64081
# The coefficient for OPERATION_1347 is 36811415808.63044
# The coefficient for OPERATION_1348 is 36811415774.01718
# The coefficient for OPERATION_1357 is 36811415780.56297
# The coefficient for OPERATION_1377 is 36811415784.85451
# The coefficient for OPERATION_1379 is 36811415770.46742
# The coefficient for OPERATION_1381 is 36811415773.91196
# The coefficient for OPERATION_1383 is 36811415778.0172
# The coefficient for OPERATION_1384 is 36811415770.38567
# The coefficient for OPERATION_1388 is 36811415775.69075
# The coefficient for OPERATION_1389 is 36811415773.65958
# The coefficient for OPERATION_1390 is 36811415773.07384
# The coefficient for OPERATION_1392 is 36811415776.79523
# The coefficient for OPERATION_1394 is 36811415775.00879
# The coefficient for OPERATION_1395 is 36811415775.91167
# The coefficient for OPERATION_1396 is 36811415772.02591
# The coefficient for OPERATION_1397 is 36811415777.11122
# The coefficient for OPERATION_1398 is 36811415802.049286
# The coefficient for OPERATION_1400 is 36811415773.85449
# The coefficient for OPERATION_1403 is 36811415773.34209
# The coefficient for OPERATION_1404 is 36811415774.303665
# The coefficient for OPERATION_1405 is 36811415771.240906
# The coefficient for OPERATION_1406 is 36811415775.08652
# The coefficient for OPERATION_1407 is 36811415773.77479
# The coefficient for OPERATION_1408 is 36811415776.86508
# The coefficient for OPERATION_1409 is 36811415772.344604
# The coefficient for OPERATION_1410 is 36811415796.99919
# The coefficient for OPERATION_1411 is 36811415776.31522
# The coefficient for OPERATION_1415 is 36811415776.39649
# The coefficient for OPERATION_1418 is 36811415774.691635
# The coefficient for OPERATION_1419 is 36811415774.210236
# The coefficient for OPERATION_1421 is 36811415775.175186
# The coefficient for OPERATION_1425 is 36811415803.54898
# The coefficient for OPERATION_1426 is 36811415784.64032
# The coefficient for OPERATION_1428 is 36811415784.8163
# The coefficient for OPERATION_1435 is 36811415792.251976
# The coefficient for OPERATION_1437 is 36811415770.5152
# The coefficient for OPERATION_1438 is 36811415774.351395
# The coefficient for OPERATION_1439 is 36811415779.794
# The coefficient for OPERATION_1440 is 36811415774.89557
# The coefficient for OPERATION_1441 is 36811415794.24312
# The coefficient for OPERATION_1442 is 36811415773.581406
# The coefficient for OPERATION_1458 is 36811415770.92529
# The coefficient for OPERATION_1459 is 36811415783.1005
# The coefficient for OPERATION_1460 is 36811415776.30313
# The coefficient for OPERATION_1465 is 36811415810.97986
# The coefficient for OPERATION_1466 is 36811415775.91637
# The coefficient for OPERATION_1467 is 36811415795.000336
# The coefficient for OPERATION_1472 is 36811415787.493416
# The coefficient for OPERATION_1483 is 36811415770.47774
# The coefficient for OPERATION_1485 is 36811415806.31443
# The coefficient for OPERATION_1574 is 36811415774.82069
# The coefficient for OPERATION_1575 is 36811415787.8504
# The coefficient for OPERATION_1576 is 36811415774.03554
# The coefficient for OPERATION_1577 is 36811415770.01388
# The coefficient for OPERATION_1602 is 36811415770.89691
# The coefficient for OPERATION_1603 is 36811415770.42607
# The coefficient for OPERATION_1609 is 36811415772.094284
# The coefficient for OPERATION_1612 is 36811415780.81321
# The coefficient for OPERATION_1613 is 36811415815.16897
# The coefficient for OPERATION_1642 is 36811415774.74724
# The coefficient for OPERATION_1644 is 36811415771.65345
# The coefficient for OPERATION_1645 is 36811415772.58899
# The coefficient for OPERATION_1663 is 36811415775.95024
# The coefficient for OPERATION_1674 is 36811415771.00704
# The coefficient for OPERATION_1677 is 36811415774.57411
# The coefficient for OPERATION_1682 is 36811415773.32048
# The coefficient for OPERATION_1689 is 36811415786.10302
# The coefficient for OPERATION_1690 is 36811415780.05097
# The coefficient for OPERATION_1692 is 36811415777.7541
# The coefficient for OPERATION_1696 is 36811415776.389084
# The coefficient for OPERATION_1699 is 36811415775.80203
# The coefficient for OPERATION_1700 is 36811415775.79668
# The coefficient for OPERATION_1707 is 36811415772.28934
# The coefficient for OPERATION_1708 is 36811415781.893265
# The coefficient for OPERATION_1709 is 36811415773.73471
# The coefficient for OPERATION_1710 is 36811415813.65224
# The coefficient for OPERATION_1720 is 36811415781.6837
# The coefficient for OPERATION_1728 is 36811415831.821915
# The coefficient for OPERATION_1730 is 36811415784.46858
# The coefficient for OPERATION_1740 is 36811415795.181435
# The coefficient for OPERATION_1742 is 36811415770.26947
# The coefficient for OPERATION_1743 is 36811415771.661865
# The coefficient for OPERATION_1746 is 36811415808.91306
# The coefficient for OPERATION_1766 is 36811415776.18103
# The coefficient for OPERATION_1767 is 36811415775.57668
# The coefficient for OPERATION_1768 is 36811415773.79825
# The coefficient for OPERATION_1769 is 36811415781.81746
# The coefficient for OPERATION_1770 is 36811415776.22873
# The coefficient for OPERATION_1783 is 36811415770.97679
# The coefficient for OPERATION_1793 is 36811415778.18493
# The coefficient for OPERATION_1797 is 36811415776.81999
# The coefficient for OPERATION_1798 is 36811415774.56898
# The coefficient for OPERATION_1803 is 36811415775.457535
# The coefficient for OPERATION_1839 is 36811415784.7962
# The coefficient for OPERATION_1842 is 36811415773.28673
# The coefficient for OPERATION_1843 is 36811415778.56578
# The coefficient for OPERATION_1852 is 36811415783.725235
# The coefficient for OPERATION_1853 is 36811415775.82202
# The coefficient for OPERATION_1859 is 36811415773.49117
# The coefficient for OPERATION_1862 is 36811415817.895
# The coefficient for OPERATION_1863 is 36811415808.943756
# The coefficient for OPERATION_1864 is 36811415771.17766
# The coefficient for OPERATION_1895 is 36811415775.64162
# The coefficient for OPERATION_1896 is 36811415775.47078
# The coefficient for OPERATION_1898 is 36811415780.91394
# The coefficient for OPERATION_1965 is 36811415870.48852
# The coefficient for OPERATION_1966 is 36811415821.90402
# The coefficient for OPERATION_1975 is 36811415775.75584
# The coefficient for OPERATION_1976 is 36811415798.12077
# The coefficient for OPERATION_1980 is 36811415774.73334
# The coefficient for OPERATION_1987 is 36811415794.7448
# The coefficient for OPERATION_1998 is 36811415778.28376
# The coefficient for OPERATION_2001 is 36811415779.44702
# The coefficient for OPERATION_2002 is 36811415775.904495
# The coefficient for OPERATION_2007 is 36811415774.6756
# The coefficient for OPERATION_2009 is 36811415781.74757
# The coefficient for OPERATION_2014 is 36811415775.0197
# The coefficient for OPERATION_2016 is 36811415791.356995
# The coefficient for OPERATION_2020 is 36811415843.424255
# The coefficient for OPERATION_2024 is 36811415826.75458
# The coefficient for OPERATION_2025 is 36811415776.23996
# The coefficient for OPERATION_2026 is 36811415781.721375
# The coefficient for OPERATION_2027 is 36811415781.883286
# The coefficient for OPERATION_2030 is 36811415783.00011
# The coefficient for OPERATION_2031 is 36811415785.07886
# The coefficient for OPERATION_2034 is 36811415789.43015
# The coefficient for OPERATION_2036 is 36811415773.724014
# The coefficient for OPERATION_2037 is 36811415773.535904
# The coefficient for OPERATION_2039 is 36811415818.4771
# The coefficient for OPERATION_2040 is 36811415775.037384
# The coefficient for OPERATION_2042 is 36811415775.14188
# The coefficient for OPERATION_2049 is 36811415789.01756
# The coefficient for OPERATION_2065 is 36811415777.2981
# The coefficient for OPERATION_2066 is 36811415809.00244
# The coefficient for OPERATION_2067 is 36811415803.2566
# The coefficient for OPERATION_2068 is 36811415782.00772
# The coefficient for OPERATION_2069 is 36811415778.325966
# The coefficient for OPERATION_2070 is 36811415777.23751
# The coefficient for OPERATION_2071 is 36811415782.58244
# The coefficient for OPERATION_2077 is 36811415773.63167
# The coefficient for OPERATION_2078 is 36811415778.55437
# The coefficient for OPERATION_2079 is 36811415787.765686
# The coefficient for OPERATION_2080 is 36811415774.931015
# The coefficient for OPERATION_2081 is 36811415789.0108
# The coefficient for OPERATION_2082 is 36811415811.4833
# The coefficient for OPERATION_2092 is 36811415779.5537
# The coefficient for OPERATION_2093 is 36811415770.02164
# The coefficient for OPERATION_2096 is 36811415784.62614
# The coefficient for OPERATION_2098 is 36811415772.4803
# The coefficient for OPERATION_2099 is 36811415802.98415
# The coefficient for OPERATION_2100 is 36811415824.2063
# The coefficient for OPERATION_2101 is 36811415788.89467
# The coefficient for OPERATION_2103 is 36811415779.96622
# The coefficient for OPERATION_2105 is 36811415773.209724
# The coefficient for OPERATION_2106 is 36811415818.309845
# The coefficient for OPERATION_2107 is 36811415775.06268
# The coefficient for OPERATION_2111 is 36811415770.62197
# The coefficient for OPERATION_2125 is 36811415776.297386
# The coefficient for OPERATION_2131 is 36811415770.92192
# The coefficient for OPERATION_2133 is 36811415803.7845
# The coefficient for OPERATION_2134 is 36811415779.04414
# The coefficient for OPERATION_2135 is 36811415770.04262
# The coefficient for OPERATION_2140 is 36811415785.02147
# The coefficient for OPERATION_2141 is 36811415777.49548
# The coefficient for OPERATION_2142 is 36811415770.36868
# The coefficient for OPERATION_2144 is 36811415820.77173
# The coefficient for OPERATION_2145 is 36811415778.31171
# The coefficient for OPERATION_2146 is 36811415788.5192
# The coefficient for OPERATION_2147 is 36811415776.34247
# The coefficient for OPERATION_2148 is 36811415770.68236
# The coefficient for OPERATION_2149 is 36811415770.268295
# The coefficient for OPERATION_2150 is 36811415797.22401
# The coefficient for OPERATION_2151 is 36811415893.53444
# The coefficient for OPERATION_2155 is 290289253150.67957
# The coefficient for OPERATION_2156 is 36811415773.13889
# The coefficient for OPERATION_2160 is 36811415771.36422
# The coefficient for OPERATION_2162 is 36811415818.71972
# The coefficient for OPERATION_2163 is 36811415843.40794
# The coefficient for OPERATION_2164 is 36811415825.31048
# The coefficient for OPERATION_2165 is 36811415770.674255
# The coefficient for OPERATION_2167 is 36811415823.960815
# The coefficient for OPERATION_2169 is 36811415793.67546
# The coefficient for OPERATION_2171 is 36811415783.70755
# The coefficient for OPERATION_2177 is 36811415774.23894
# The coefficient for OPERATION_2182 is 36811415782.019104
# The coefficient for OPERATION_2188 is 36811415773.922585
# The coefficient for OPERATION_2189 is 36811415775.02002
# The coefficient for OPERATION_2192 is 36811415785.04061
# The coefficient for OPERATION_2204 is 36811415801.854095
# The coefficient for OPERATION_2206 is 36811415775.224655
# The coefficient for OPERATION_2208 is 36811415778.33487
# The coefficient for OPERATION_2209 is 36811415775.892166
# The coefficient for OPERATION_2210 is 36811415774.573456
# The coefficient for OPERATION_2211 is 36811415775.0022
# The coefficient for OPERATION_2212 is 36811415776.81607
# The coefficient for OPERATION_2213 is 36811415806.05823
# The coefficient for OPERATION_2215 is 36811415770.89
# The coefficient for OPERATION_2216 is 36811415781.46103
# The coefficient for OPERATION_2219 is 36811415776.082054
# The coefficient for OPERATION_2220 is 36811415788.30615
# The coefficient for OPERATION_2221 is 36811415797.7455
# The coefficient for OPERATION_2223 is 36811415794.897316
# The coefficient for OPERATION_2224 is 36811415855.64442
# The coefficient for OPERATION_2226 is 36811415776.09564
# The coefficient for OPERATION_2233 is 36811415901.70267
# The coefficient for OPERATION_2234 is 36811415800.19057
# The coefficient for OPERATION_2235 is 36811415778.8118
# The coefficient for OPERATION_2236 is 36811415770.01259
# The coefficient for OPERATION_2237 is 36811415811.88284
# The coefficient for OPERATION_2238 is 36811415770.7585
# The coefficient for OPERATION_2239 is 36811415773.027405
# The coefficient for OPERATION_2241 is 36811415783.84415
# The coefficient for OPERATION_2242 is 36811415781.24364
# The coefficient for OPERATION_2243 is 36811415771.101715
# The coefficient for OPERATION_2244 is 36811415774.459724
# The coefficient for OPERATION_2245 is 36811415770.81407
# The coefficient for OPERATION_2246 is 36811415774.1311
# The coefficient for OPERATION_2255 is 36811415772.48694
# The coefficient for OPERATION_2258 is 36811415796.73331
# The coefficient for OPERATION_2262 is 36811415827.59296
# The coefficient for OPERATION_2263 is 36811415873.15086
# The coefficient for OPERATION_2264 is 36811415770.012924
# The coefficient for OPERATION_2266 is 36811415785.6483
# The coefficient for OPERATION_2277 is 36811415781.120705
# The coefficient for OPERATION_2289 is 36811415805.975586
# The coefficient for OPERATION_2308 is 36811415777.21298
# The coefficient for OPERATION_2312 is 36811415770.46666
# The coefficient for OPERATION_2323 is 36811415770.870514
# The coefficient for OPERATION_2324 is 36811415771.40764
# The coefficient for OPERATION_2325 is 36811415770.88151
# The coefficient for OPERATION_2326 is 36811415771.67221
# The coefficient for OPERATION_2327 is 36811415770.806435
# The coefficient for OPERATION_2328 is 36811415770.789795
# The coefficient for OPERATION_2329 is 36811415770.649155
# The coefficient for OPERATION_2330 is 36811415770.69722
# The coefficient for OPERATION_2332 is 36811415771.26068
# The coefficient for OPERATION_2333 is 36811415771.46362
# The coefficient for OPERATION_2334 is 36811415771.31645
# The coefficient for OPERATION_2335 is 36811415845.21741
# The coefficient for OPERATION_2336 is 36811416065.14671
# The coefficient for OPERATION_2341 is 36811415770.80552
# The coefficient for OPERATION_2343 is 36811415776.00607
# The coefficient for OPERATION_2344 is 36811415775.75453
# The coefficient for OPERATION_2345 is 36811415775.84911
# The coefficient for OPERATION_2346 is 36811415777.733376
# The coefficient for OPERATION_2347 is 36811415776.14176
# The coefficient for OPERATION_2348 is 36811415788.67009
# The coefficient for OPERATION_2350 is 36811415777.57833
# The coefficient for OPERATION_2355 is 36811415777.96808
# The coefficient for OPERATION_2356 is 36811415778.96656
# The coefficient for OPERATION_2377 is 25090616682.91209
# The coefficient for OPERATION_2477 is 36811415827.19019
# The coefficient for OPERATION_2478 is 36811415844.736336
# The coefficient for OPERATION_2480 is 36811415776.24708
# The coefficient for OPERATION_2494 is 36811415780.37038
# The coefficient for OPERATION_2558 is 36811415806.02281
# The coefficient for OPERATION_2700 is 36811415772.96919
# The coefficient for OPERATION_2750 is 36811415787.78997
# The coefficient for OPERATION_2812 is 36811415770.00933
# The coefficient for OPERATION_2925 is 36811415842.80634
# The coefficient for OPERATION_3021 is 36811415770.019264
# The coefficient for OPERATION_3077 is 36811415829.65176
# The coefficient for OPERATION_3083 is 36811415785.347595
# The coefficient for OPERATION_3099 is 36811415793.96149
# The coefficient for OPERATION_3102 is 36811415780.89533
# The coefficient for OPERATION_3103 is 36811415831.00046
# The coefficient for OPERATION_3126 is 36811415992.580795
# The coefficient for OPERATION_3148 is 36811415776.08901
# The coefficient for OPERATION_3149 is 36811415770.21427
# The coefficient for OPERATION_3195 is 36811415776.730774
# The coefficient for OPERATION_3196 is 36811415775.09158
# The coefficient for OPERATION_3197 is 36811415778.056206
# The coefficient for OPERATION_3198 is 36811415774.22287
# The coefficient for OPERATION_3199 is 36811415789.96009
# The coefficient for OPERATION_4212 is 36811415770.19924
# The coefficient for OPERATION_4249 is 36811415822.7911
# The coefficient for OPERATION_4324 is 36811415819.73526
# The coefficient for OPERATION_4326 is 36811415799.64694
# The coefficient for OPERATION_4327 is 36811415782.28432
# The coefficient for OPERATION_4368 is 36811415807.32506
# The coefficient for OPERATION_5165 is 36811415773.47678
# The coefficient for OPERATION_5824 is 36811415772.945076
# The coefficient for OPERATION_5825 is 36811415773.34431
# The coefficient for OPERATION_5826 is 36811415772.61536
# The coefficient for OPERATION_5827 is 36811415772.542465
# The coefficient for OPERATION_6298 is 36811415777.45233
# The coefficient for OPERATION_6299 is 36811415776.05444
# The coefficient for OPERATION_6300 is 36811415777.04237
# The coefficient for OPERATION_6301 is 36811415770.01465
# The coefficient for OPERATION_6302 is 36811415772.95944
# The coefficient for OPERATION_6312 is 36811415777.3627
# The coefficient for OPERATION_6336 is 36811415872.474205
# The coefficient for OPERATION_6337 is 1293351671272.1797
# The coefficient for OPERATION_6338 is 36811415812.010376
# The coefficient for OPERATION_6339 is 36811415874.74712
# The coefficient for OPERATION_6370 is 36811415784.34334
# The coefficient for OPERATION_6381 is 8725309382225.646
# The coefficient for OPERATION_6385 is 36811415806.52606
# The coefficient for OPERATION_6386 is 36811415775.3866
# The coefficient for OPERATION_6387 is 36811415776.20741
# The coefficient for OPERATION_6388 is 36811415813.12177
# The coefficient for OPERATION_6389 is 36811415775.75537
# The coefficient for OPERATION_6415 is 36811415811.64366
# The coefficient for OPERATION_6416 is 36811415788.11276
# The coefficient for OPERATION_6417 is 36811415785.90239
# The coefficient for OPERATION_6418 is 36811415794.066345
# The coefficient for OPERATION_6421 is 36811415812.94526
# The coefficient for OPERATION_6435 is 36811415849.89965
# The coefficient for OPERATION_6436 is 36811415778.596985
# The coefficient for OPERATION_6437 is 36811415790.737526
# The coefficient for OPERATION_6438 is 36811415770.013725
# The coefficient for OPERATION_6439 is 36811415773.664116
# The coefficient for OPERATION_6440 is 36811415816.50246
# The coefficient for OPERATION_6452 is 36811415772.37765
# The coefficient for OPERATION_6460 is 36811415788.89764
# The coefficient for OPERATION_6461 is 36811415772.71021
# The coefficient for OPERATION_6463 is 36811415778.03369
# The coefficient for OPERATION_6478 is 36811415839.32175
# The coefficient for OPERATION_6489 is 36811415842.54757
# The coefficient for OPERATION_6490 is 36811415861.86946
# The coefficient for OPERATION_6525 is 36811415771.525635
# The coefficient for OPERATION_6527 is 36811415771.391426
# The coefficient for OPERATION_6549 is 36811415776.01192
# The coefficient for OPERATION_6550 is 36811415778.41235
# The coefficient for OPERATION_6551 is 36811415773.66898
# The coefficient for OPERATION_6552 is 36811415777.579384
# The coefficient for OPERATION_6559 is 36811415771.83295
# The coefficient for OPERATION_6565 is 36811415774.41669
# The coefficient for OPERATION_6567 is 36811415773.83792
# The coefficient for OPERATION_6568 is 36811415776.023544
# The coefficient for OPERATION_6569 is 36811415815.079445
# The coefficient for OPERATION_6605 is 36811415777.49224
# The coefficient for OPERATION_6608 is 36811415775.74776
# The coefficient for OPERATION_6610 is 36811415772.631966
# The coefficient for OPERATION_6618 is 36811415773.12872
# The coefficient for OPERATION_6626 is 2476648299522.195
# The coefficient for OPERATION_6649 is 36811415814.111786
# The coefficient for OPERATION_6684 is 36811415775.601074
# The coefficient for OPERATION_6690 is 36811415770.026024
# The coefficient for OPERATION_6692 is 36811415770.013756
# The coefficient for OPERATION_6694 is 36811415772.816025
# The coefficient for OPERATION_6696 is 36811415773.62142
# The coefficient for OPERATION_6698 is 36811415772.601166
# The coefficient for OPERATION_6699 is 36811415771.37303
# The coefficient for OPERATION_6702 is 36811415770.814095
# The coefficient for OPERATION_6715 is 36811415770.21694
# The coefficient for OPERATION_6716 is 36811415781.435936
# The coefficient for OPERATION_6720 is 36811415805.53319
# The coefficient for OPERATION_6727 is 36811415770.17067
# The coefficient for OPERATION_6744 is 36811415826.17385
# The coefficient for OPERATION_6794 is 36811415783.417694
# The coefficient for OPERATION_6797 is 36811416010.165276
# The coefficient for OPERATION_6800 is 7784500683168.179
# The coefficient for OPERATION_6805 is 36811415784.20056
# The coefficient for OPERATION_6849 is 36811415773.25436
# The coefficient for OPERATION_6895 is 36811415858.04245
# The coefficient for OPERATION_6901 is 36811415770.66743
# The coefficient for OPERATION_6904 is 36811415937.99921
# The coefficient for OPERATION_6905 is 36811415921.927025
# The coefficient for OPERATION_6940 is 36811415770.057
# The coefficient for OPERATION_6984 is 36811415775.50463
# The coefficient for OPERATION_6994 is 36811415800.09463
# The coefficient for OPERATION_6998 is 36811415770.01218
# The coefficient for OPERATION_7021 is 3130464986.1437216
# The coefficient for OPERATION_7054 is 36811415825.341484
# The coefficient for OPERATION_7055 is 36811415798.403854
# The coefficient for OPERATION_7056 is 36811415828.55272
# The coefficient for OPERATION_7057 is 36811415796.98353
# The coefficient for OPERATION_7058 is 36811415798.47222
# The coefficient for OPERATION_7059 is 36811415770.72574
# The coefficient for OPERATION_7062 is 36811415803.18027
# The coefficient for OPERATION_7098 is 36811415770.42805
# The coefficient for OPERATION_7114 is 36811415770.04359
# The coefficient for OPERATION_7118 is 36811415770.003876
# The coefficient for OPERATION_7132 is 36811415788.280334
# The coefficient for OPERATION_7140 is 36811415778.78882
# The coefficient for OPERATION_7141 is 36811415772.08372
# The coefficient for OPERATION_7142 is 36811415771.16221
# The coefficient for OPERATION_7143 is 36811415895.766426
# The coefficient for OPERATION_7153 is 2096175230.946332
# The coefficient for OPERATION_7155 is 36811415770.69632
# The coefficient for OPERATION_7156 is 36811415770.88738
# The coefficient for OPERATION_7157 is 36811415776.433334
# The coefficient for OPERATION_7158 is 36811415774.52336
# The coefficient for OPERATION_7162 is 36811415773.95152
# The coefficient for OPERATION_7168 is 36811415812.8646
# The coefficient for OPERATION_7170 is 36811415883.50641
# The coefficient for OPERATION_7180 is 36811415776.07897
# The coefficient for OPERATION_7233 is 36811415864.153435
# The coefficient for OPERATION_7235 is 36811415800.53494
# The coefficient for OPERATION_7236 is 36811415771.13247
# The coefficient for OPERATION_7257 is 36811415774.04075
# The coefficient for OPERATION_7283 is 36811415774.79483
# The coefficient for OPERATION_7288 is 36811415778.070694
# The coefficient for OPERATION_7374 is 36811415837.78745
# The coefficient for OPERATION_7377 is 36811415802.56973
# The coefficient for OPERATION_7399 is 36811415772.00939
# The coefficient for OPERATION_7468 is 36811415814.55497
# The coefficient for OPERATION_7469 is 36811415771.2782
# The coefficient for OPERATION_7470 is 36811415795.76308
# The coefficient for OPERATION_7473 is 36811415775.10022
# The coefficient for OPERATION_7483 is 36811415783.44748
# The coefficient for OPERATION_7500 is 36811415771.07239
# The coefficient for OPERATION_7509 is 36811415772.029144
# The coefficient for OPERATION_7517 is 36811415771.10445
# The coefficient for OPERATION_7518 is 36811415778.38377
# The coefficient for OPERATION_7519 is 36811415774.15424
# The coefficient for OPERATION_7527 is 36811415771.5358
# The coefficient for OPERATION_7529 is 36811415772.01172
# The coefficient for OPERATION_7541 is 36811415771.59938
# The coefficient for OPERATION_7563 is 36811415770.02443
# The coefficient for OPERATION_7568 is 36811415771.28151
# The coefficient for OPERATION_7570 is 36811415788.22834
# The coefficient for OPERATION_7572 is 36811415770.241295
# The coefficient for OPERATION_7582 is 36811415771.96535
# The coefficient for OPERATION_7594 is 36811415804.22948
# The coefficient for OPERATION_7623 is 36811415775.26107
# The coefficient for OPERATION_7624 is 36811415791.75105
# The coefficient for OPERATION_7633 is 36811415813.85527
# The coefficient for OPERATION_7634 is 36811415807.45452
# The coefficient for OPERATION_7635 is 36811415834.78251
# The coefficient for OPERATION_7636 is 36811415810.583626
# The coefficient for OPERATION_7637 is 36811415903.28589
# The coefficient for OPERATION_7638 is 36811415846.0055
# The coefficient for OPERATION_7645 is 36811415770.98798
# The coefficient for OPERATION_7647 is 36811415770.43234
# The coefficient for OPERATION_7648 is 36811415772.24614
# The coefficient for OPERATION_7658 is 36811415777.3861
# The coefficient for OPERATION_7683 is 36811415772.2399
# The coefficient for OPERATION_7744 is 36811415778.01953
# The coefficient for OPERATION_7767 is 36811415828.63274
# The coefficient for OPERATION_7784 is 36811415792.11157
# The coefficient for OPERATION_7884 is 36811415801.1924
# The coefficient for OPERATION_7885 is 36811415787.05146
# The coefficient for OPERATION_7886 is 36811415789.6644
# The coefficient for OPERATION_7894 is 36811415819.537735
# The coefficient for OPERATION_7895 is 36811415788.99205
# The coefficient for OPERATION_7896 is 36811415797.59944
# The coefficient for OPERATION_7897 is 36811415797.135506
# The coefficient for OPERATION_7899 is 36811415771.29239
# The coefficient for OPERATION_7900 is 36811415816.68264
# The coefficient for OPERATION_7901 is 36811415772.21265
# The coefficient for OPERATION_7904 is 36811415797.63802
# The coefficient for OPERATION_7905 is 36811415781.832825
# The coefficient for OPERATION_7906 is 36811415790.398186
# The coefficient for OPERATION_7914 is 36811415790.07268
# The coefficient for OPERATION_7915 is 36811415784.52237
# The coefficient for OPERATION_7916 is 36811415782.1492
# The coefficient for OPERATION_7917 is 36811415776.433136
# The coefficient for OPERATION_7930 is 36811415780.74881
# The coefficient for OPERATION_7948 is 36811415860.660995
# The coefficient for OPERATION_7960 is 36811415806.666245
# The coefficient for OPERATION_8024 is 36811415802.0788
# The coefficient for OPERATION_8026 is 36811415785.84595
# The coefficient for OPERATION_8044 is 36811415773.368195
# The coefficient for OPERATION_8072 is 36811415808.94061
# The coefficient for OPERATION_8077 is 36811415770.56088
# The coefficient for OPERATION_8079 is 36811415777.43974
# The coefficient for OPERATION_8081 is 36811415780.971375
# The coefficient for OPERATION_8147 is 36811415797.65796
# The coefficient for OPERATION_8153 is 36811415819.55445
# The coefficient for OPERATION_8154 is 36811415785.88418
# The coefficient for OPERATION_8156 is 36811415775.65435
# The coefficient for OPERATION_8183 is 36811415772.0227
# The coefficient for OPERATION_8193 is 36811415771.53993
# The coefficient for OPERATION_8758 is 36811415770.1508
# The coefficient for OPERATION_8777 is 36811415919.037
# The coefficient for OPERATION_8778 is 36811415782.76378
# The coefficient for OPERATION_8859 is 36811415772.28653
# The coefficient for OPERATION_8940 is 36811415776.21108
# The coefficient for OPERATION_9081 is 36811415779.23637
# The coefficient for OPERATION_9374 is 36811415777.424866
# The coefficient for OPERATION_9375 is 36811415782.789314
# The coefficient for OPERATION_9376 is 36811415772.27192
# The coefficient for OPERATION_9384 is 36811415803.12492
# The coefficient for OPERATION_9385 is 0.0
# The coefficient for OPERATION_9387 is 36811415770.95322
